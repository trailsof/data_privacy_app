# %% [markdown]
# # lets explore the data

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/app_permissions.csv')

# %%
df.permission.value_counts()
# Out:
# permission
# find accounts on the device                                                         6
# modify or delete the contents of your USB storage                                   6
# read phone status and identity                                                      6
# read the contents of your USB storage                                               6
# read your own contact card                                                          3
# add or remove accounts                                                              3
# directly call phone numbers                                                         3
# precise location (GPS and network-based)                                            3
# read your contacts                                                                  3
# read call log                                                                       3
# record audio                                                                        3
# ...

# %%
df.loc[df['category'] == 'Contacts']
# Out:
#                    app_id  category                   permission
# 4   com.instagram.android  Contacts  find accounts on the device
# 5   com.instagram.android  Contacts           read your contacts
# 41    com.facebook.katana  Contacts  find accounts on the device
# 42    com.facebook.katana  Contacts         modify your contacts
# 43    com.facebook.katana  Contacts           read your contacts
# 84           com.whatsapp  Contacts  find accounts on the device
# 85           com.whatsapp  Contacts         modify your contacts
# 86           com.whatsapp  Contacts           read your contacts

# %%
df[df['category'] == 'Other']
# Out:
#                     app_id category                         permission
# 18   com.instagram.android    Other          access Bluetooth settings
# 19   com.instagram.android    Other        change network connectivity
# 20   com.instagram.android    Other         change your audio settings
# 21   com.instagram.android    Other  connect and disconnect from Wi-Fi
# 22   com.instagram.android    Other                  control vibration
# 23   com.instagram.android    Other  create accounts and set passwords
# 24   com.instagram.android    Other                full network access
# 25   com.instagram.android    Other                  install shortcuts
# 26   com.instagram.android    Other        pair with Bluetooth devices
# 27   com.instagram.android    Other       prevent device from sleeping
# 28   com.instagram.android    Other               reorder running apps
# 29   com.instagram.android    Other                     run at startup
# ...
